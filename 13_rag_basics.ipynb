# %%
from pathlib import Path

# 当前工作目录（推荐）
SCRIPT_DIR = Path.cwd()

# 创建 data 文件夹路径
DATA_DIR = SCRIPT_DIR / "data"

# 创建目录（如果不存在）
DATA_DIR.mkdir(exist_ok=True)

print(DATA_DIR)
# Out:
# /Users/humengqing/Documents/Code/VSCode/langchain/data

# %%
print("\n--- 测试 1: 文档加载 ---")

from langchain_community.document_loaders import TextLoader
import os

test_content="""一个炎热的上午，熊妈妈带着小熊在一棵大树下乘凉。忽然，空中传来轰隆隆一声巨响，熊妈妈说：“要下雨了，我们找个地方避一下。”熊妈妈带着小熊向附近的一个山洞跑去。跑进山洞不久，大雨便倾盆而下。望着洞外的大雨，小熊靠在妈妈身上，身体有些颤抖。熊妈妈说：“孩子，别怕，是打雷发出的声响！”小熊说：“下雨就下雨吧，为什么会打雷呢？”熊妈妈沉思片刻，然后说：“有个故事，我讲给你听听。在天上，居住着雷公和电母，他们是一对天神，掌管着天庭的雷电。雷公视力差，难辨黑白，电母便寸步不离，捧着镜子，在前面探路。电母发现恶人后，便告诉雷公，雷公便投下一个响雷，这时，只听轰隆隆一声巨响，人们便会看到乌云密布，狂风大作，飞沙走石，大雨倾盆。与此同时，电母还会射出耀眼的利剑，这便是我们看到的闪电，雷电过后，人们便会发现恶人已经是身首异处……”“雷公和电母好厉害呀！”小熊说，“怎么能找到雷公和电母呢，我要告诉雷公和电母，有些人把好多小熊都捉走了， 我要让雷公和电母教训这些恶人！”熊妈妈说：“雷公和电母都是藏在大雨中的，他们能看到我们，我们却看不到他们。但我们可以相信，那些作恶的坏人，总有一天会被雷公和电母发现的。”小熊点点头，看着洞口外面的大雨。他希望能够看到藏在雨中的雷公和电母。可是，直到大雨过去，天空放晴，他也没看到雷公和电母的影子。大雨过后，熊妈妈又带着小熊在山林里找吃的。走着走着，一只小猴一个跟头从树上跳到了小熊面前。小熊一哆嗦，然后说：“吓我一跳，我还以为是谁呢！”小猴说：“小熊，走，我们到河边看大水去，大水冲下来好多东西呢，说不定也会有大鱼被冲下来！”小熊很高兴，跟妈妈告别以后，便和小猴一起向河边跑去。来到河边，只见滔滔洪水裹挟着树枝杂物滚滚而下。这时，小熊想起了妈妈讲的有关雷电的故事，他便把这个故事讲给小猴听。正在小猴津津有味的听小熊讲故事的时候，小鹦鹉的声音忽然在空中响起：“不对，小熊讲的不对！”小熊望着停在树上的小鹦鹉说：“哪里讲得不对了，你讲一个给我们听听！”小鹦鹉说：“我有一次到一棵大槐树上去找虫子吃，这棵大树的旁边是一个教室，我听到了老师给学生讲雷电的知识。老师说，天上根本就没有什么雷公电母，那只是一种神话传说罢了。”小猴问道：“那老师是怎么讲雷电的呢？”小鹦鹉说：“老师说，雷电是一种自然放电现象。夏天的时候，高空中有好多云团在不断运动，云团交错运动，相互摩擦，从而产生大量的电荷，形成电场。由于同种电荷相互排斥，所以正电荷与负电荷分别聚集到云的两端。积云所带的电达到一定程度时，就会穿过空气放电，而放电使空气振动发出声音，这便是雷声。因为空气的电阻不均匀，电前进的形状大多曲曲折折，形成象树枝一样的光带，这就是闪电。”
"""

test_file = DATA_DIR / "test.txt"

with open(test_file, "w", encoding="utf-8") as f:
    f.write(test_content)

# 加载文档
loader = TextLoader(test_file, encoding="utf-8")
documents = loader.load()

print(f"\n[OK] 文档加载成功")
print(f"  文档数: {len(documents)}")
print(f"  内容长度: {len(documents[0].page_content)} 字符")
print(f"  元数据: {documents[0].metadata}")
# Out:
# --- 测试 1: 文档加载 ---
#
# [OK] 文档加载成功
#   文档数: 1
#   内容长度: 1123 字符
#   元数据: {'source': '/Users/humengqing/Documents/Code/VSCode/langchain/data/test.txt'}

# %%
print("\n--- 测试 2: 文本分割 ---")

from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=50,
    chunk_overlap=20,
    # separators=["\n\n", "\n", "。", " ", ""]
)

chunks = splitter.split_documents(documents)

print(f"\n[OK] 文本分割成功")
print(f"  原文档数: {len(documents)}")
print(f"  分割后: {len(chunks)} 块")
for i, chunk in enumerate(chunks, 1):
    print(f"块 {i}: {chunk.page_content}")
# Out:
# --- 测试 2: 文本分割 ---
#
# [OK] 文本分割成功
#   原文档数: 1
#   分割后: 37 块
# 块 1: 一个炎热的上午，熊妈妈带着小熊在一棵大树下乘凉。忽然，空中传来轰隆隆一声巨响，熊妈妈说：“要下雨了，
# 块 2: 来轰隆隆一声巨响，熊妈妈说：“要下雨了，我们找个地方避一下。”熊妈妈带着小熊向附近的一个山洞跑去。跑
# 块 3: ”熊妈妈带着小熊向附近的一个山洞跑去。跑进山洞不久，大雨便倾盆而下。望着洞外的大雨，小熊靠在妈妈身上
# 块 4: 盆而下。望着洞外的大雨，小熊靠在妈妈身上，身体有些颤抖。熊妈妈说：“孩子，别怕，是打雷发出的声响！”
# 块 5: 妈说：“孩子，别怕，是打雷发出的声响！”小熊说：“下雨就下雨吧，为什么会打雷呢？”熊妈妈沉思片刻，然
# 块 6: 吧，为什么会打雷呢？”熊妈妈沉思片刻，然后说：“有个故事，我讲给你听听。在天上，居住着雷公和电母，他
# 块 7: 讲给你听听。在天上，居住着雷公和电母，他们是一对天神，掌管着天庭的雷电。雷公视力差，难辨黑白，电母便
# 块 8: 天庭的雷电。雷公视力差，难辨黑白，电母便寸步不离，捧着镜子，在前面探路。电母发现恶人后，便告诉雷公，
# 块 9: 在前面探路。电母发现恶人后，便告诉雷公，雷公便投下一个响雷，这时，只听轰隆隆一声巨响，人们便会看到乌
# 块 10: 这时，只听轰隆隆一声巨响，人们便会看到乌云密布，狂风大作，飞沙走石，大雨倾盆。与此同时，电母还会射出
# 块 11: 沙走石，大雨倾盆。与此同时，电母还会射出耀眼的利剑，这便是我们看到的闪电，雷电过后，人们便会发现恶人
# 块 12: 们看到的闪电，雷电过后，人们便会发现恶人已经是身首异处……”“雷公和电母好厉害呀！”小熊说，“怎么能
# 块 13: “雷公和电母好厉害呀！”小熊说，“怎么能找到雷公和电母呢，我要告诉雷公和电母，有些人把好多小熊都捉走
# 块 14: 要告诉雷公和电母，有些人把好多小熊都捉走了，
# 块 15: 我要让雷公和电母教训这些恶人！”熊妈妈说：“雷公和电母都是藏在大雨中的，他们能看到我们，我们却看不
# 块 16: 藏在大雨中的，他们能看到我们，我们却看不到他们。但我们可以相信，那些作恶的坏人，总有一天会被雷公和电
# ...

# %%
print("\n--- 测试 2: 文本分割 ---")

from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=50,
    chunk_overlap=20,
    separators=["\n\n", "\n", "。", " ", ""]
)

chunks = splitter.split_documents(documents)

print(f"\n[OK] 文本分割成功")
print(f"  原文档数: {len(documents)}")
print(f"  分割后: {len(chunks)} 块")
for i, chunk in enumerate(chunks, 1):
    print(f"块 {i}: {chunk.page_content}")
# Out:
# --- 测试 2: 文本分割 ---
#
# [OK] 文本分割成功
#   原文档数: 1
#   分割后: 34 块
# 块 1: 一个炎热的上午，熊妈妈带着小熊在一棵大树下乘凉
# 块 2: 。忽然，空中传来轰隆隆一声巨响，熊妈妈说：“要下雨了，我们找个地方避一下
# 块 3: 。”熊妈妈带着小熊向附近的一个山洞跑去。跑进山洞不久，大雨便倾盆而下
# 块 4: 。跑进山洞不久，大雨便倾盆而下。望着洞外的大雨，小熊靠在妈妈身上，身体有些颤抖
# 块 5: 。熊妈妈说：“孩子，别怕，是打雷发出的声响！”小熊说：“下雨就下雨吧，为什么会打雷呢？”熊妈妈沉思片
# 块 6: 就下雨吧，为什么会打雷呢？”熊妈妈沉思片刻，然后说：“有个故事，我讲给你听听
# 块 7: 。在天上，居住着雷公和电母，他们是一对天神，掌管着天庭的雷电
# 块 8: 。雷公视力差，难辨黑白，电母便寸步不离，捧着镜子，在前面探路
# 块 9: 。电母发现恶人后，便告诉雷公，雷公便投下一个响雷，这时，只听轰隆隆一声巨响，人们便会看到乌云密布，狂
# 块 10: 轰隆隆一声巨响，人们便会看到乌云密布，狂风大作，飞沙走石，大雨倾盆
# 块 11: 。与此同时，电母还会射出耀眼的利剑，这便是我们看到的闪电，雷电过后，人们便会发现恶人已经是身首异处…
# 块 12: 电过后，人们便会发现恶人已经是身首异处……”“雷公和电母好厉害呀！”小熊说，“怎么能找到雷公和电母呢
# 块 13: 害呀！”小熊说，“怎么能找到雷公和电母呢，我要告诉雷公和电母，有些人把好多小熊都捉走了，
# 块 14: 我要让雷公和电母教训这些恶人！”熊妈妈说：“雷公和电母都是藏在大雨中的，他们能看到我们，我们却看不
# 块 15: 藏在大雨中的，他们能看到我们，我们却看不到他们
# 块 16: 。但我们可以相信，那些作恶的坏人，总有一天会被雷公和电母发现的。”小熊点点头，看着洞口外面的大雨
# 块 17: 。”小熊点点头，看着洞口外面的大雨。他希望能够看到藏在雨中的雷公和电母
# 块 18: 。他希望能够看到藏在雨中的雷公和电母。可是，直到大雨过去，天空放晴，他也没看到雷公和电母的影子
# 块 19: 。大雨过后，熊妈妈又带着小熊在山林里找吃的。走着走着，一只小猴一个跟头从树上跳到了小熊面前
# ...

# %%
print("\n--- 测试 1: 文档加载 ---")

from langchain_community.document_loaders import TextLoader
import os

test_content="""The clock in Elias’s workshop did not measure time, it collected it. Each tick was a memory borrowed from somewhere else: a laugh from a distant café, a falling leaf from last autumn, the final note of a forgotten song. Elias wound the clock carefully every morning, though he knew it did not need winding. It needed attention. One evening, a girl named Mira entered the shop, carrying silence like a fragile glass. She asked if he could fix something that was not broken but missing. Elias listened, then opened the clock’s hidden panel. Inside, memories shimmered like fireflies. “Find yours,” he said. Mira reached in, hesitated, then touched a dim glow. Suddenly, the shop filled with the sound of waves and a voice calling her name. Tears slipped down her face, but she smiled. The memory returned to her, no longer lost. When she left, the clock ticked softer, as if relieved. Elias closed the panel and whispered, “Another moment returned.” Outside, the world moved forward, unaware that somewhere, time was not just passing, but being gently mended.
"""

test_file = DATA_DIR / "test_en.txt"

with open(test_file, "w", encoding="utf-8") as f:
    f.write(test_content)

# 加载文档
loader = TextLoader(test_file, encoding="utf-8")
documents = loader.load()

print(f"\n[OK] 文档加载成功")
print(f"  文档数: {len(documents)}")
print(f"  内容长度: {len(documents[0].page_content)} 字符")
print(f"  元数据: {documents[0].metadata}")
# Out:
# --- 测试 1: 文档加载 ---
#
# [OK] 文档加载成功
#   文档数: 1
#   内容长度: 1058 字符
#   元数据: {'source': '/Users/humengqing/Documents/Code/VSCode/langchain/data/test_en.txt'}

# %%
print("\n--- 测试 2: 文本分割 ---")

from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=50,
    chunk_overlap=20,
    # separators=["\n\n", "\n", "。", " ", ""]
)

chunks = splitter.split_documents(documents)

print(f"\n[OK] 文本分割成功")
print(f"  原文档数: {len(documents)}")
print(f"  分割后: {len(chunks)} 块")
for i, chunk in enumerate(chunks, 1):
    print(f"块 {i}: {chunk.page_content}")
# Out:
# --- 测试 2: 文本分割 ---
#
# [OK] 文本分割成功
#   原文档数: 1
#   分割后: 35 块
# 块 1: The clock in Elias’s workshop did not measure
# 块 2: did not measure time, it collected it. Each tick
# 块 3: it. Each tick was a memory borrowed from
# 块 4: borrowed from somewhere else: a laugh from a
# 块 5: a laugh from a distant café, a falling leaf from
# 块 6: a falling leaf from last autumn, the final note
# 块 7: the final note of a forgotten song. Elias wound
# 块 8: song. Elias wound the clock carefully every
# 块 9: carefully every morning, though he knew it did
# 块 10: he knew it did not need winding. It needed
# 块 11: winding. It needed attention. One evening, a girl
# 块 12: One evening, a girl named Mira entered the shop,
# 块 13: entered the shop, carrying silence like a fragile
# 块 14: like a fragile glass. She asked if he could fix
# 块 15: if he could fix something that was not broken but
# 块 16: was not broken but missing. Elias listened, then
# 块 17: listened, then opened the clock’s hidden panel.
# ...

# %%
print("\n--- 测试 2: 文本分割 ---")

from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=100,
    separators=["\n\n","\n","。","！","？",". "," ",""]
)

chunks = splitter.split_documents(documents)

print(f"\n[OK] 文本分割成功")
print(f"  原文档数: {len(documents)}")
print(f"  分割后: {len(chunks)} 块")
for i, chunk in enumerate(chunks, 1):
    print(f"块 {i}: {chunk.page_content}")
# Out:
# --- 测试 2: 文本分割 ---
#
# [OK] 文本分割成功
#   原文档数: 1
#   分割后: 9 块
# 块 1: The clock in Elias’s workshop did not measure time, it collected it
# 块 2: . Each tick was a memory borrowed from somewhere else: a laugh from a distant café, a falling leaf from last autumn, the final note of a forgotten song
# 块 3: . Elias wound the clock carefully every morning, though he knew it did not need winding. It needed attention. One evening, a girl named Mira entered the shop, carrying silence like a fragile glass
# 块 4: . One evening, a girl named Mira entered the shop, carrying silence like a fragile glass. She asked if he could fix something that was not broken but missing
# 块 5: . She asked if he could fix something that was not broken but missing. Elias listened, then opened the clock’s hidden panel. Inside, memories shimmered like fireflies. “Find yours,” he said
# ...

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# 嵌入测试文本
text = "LangChain 是什么"
vector = embeddings.embed_query(text)

print(f"[OK] 向量嵌入成功")
print(f"  文本: {text}")
print(f"  向量维度: {len(vector)}")
print(f"  向量前 5 个值: {[round(v, 4) for v in vector[:5]]}")
print(f"  向量后 5 个值: {[round(v, 4) for v in vector[-5:]]}")
print("vector:  ",vector)

# 计算相似度
import numpy as np

texts = [
    "LangChain 是一个框架",
    "Python 是编程语言",
    "LangChain 用于 LLM"
]

vectors = embeddings.embed_documents(texts)

def cosine_sim(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

print(f"\n\n相似度测试:")
print("texts[0]:    ",texts[0])
print("texts[1]:    ",texts[1])
print("texts[2]:    ",texts[2])
print("vectors[0]:      ",vectors[0])
print("vectors[1]:      ",vectors[1])
print("vectors[2]:      ",vectors[2])
print(f"    '{texts[0]}' vs '{texts[1]}': {cosine_sim(vectors[0], vectors[1]):.4f}")
print(f"    '{texts[0]}' vs '{texts[2]}': {cosine_sim(vectors[0], vectors[2]):.4f}")
print(f"    → 相关文本相似度更高 ✓")
# Out:
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [OK] 向量嵌入成功
#   文本: LangChain 是什么
#   向量维度: 384
#   向量前 5 个值: [-0.0086, 0.0797, 0.0801, 0.0, -0.0304]
#   向量后 5 个值: [-0.0351, 0.0516, 0.0577, 0.0667, -0.0294]
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

print("vectors[0]:      ",vectors[0])
print("vectors[1]:      ",vectors[1])
print("vectors[2]:      ",vectors[2])

print(cosine_similarity([vectors[0]], [vectors[1]]))
print(cosine_similarity([vectors[0]], [vectors[2]]))
print(cosine_similarity([vectors[1]], [vectors[2]]))
# Out:
# vectors[0]:       [0.05240878462791443, 0.08314590156078339, 0.08322550356388092, 0.011058952659368515, -0.01395311951637268, 0.03630653768777847, 0.15954996645450592, 0.004405360668897629, 0.07830677181482315, -0.050069477409124374, 0.11664095520973206, -0.09027150273323059, 0.0067400443367660046, -0.017790012061595917, -0.0022263668943196535, 0.007900567725300789, -0.09491192549467087, 0.07306879758834839, -0.061637960374355316, -0.03486768156290054, -0.03936586529016495, -0.05656062066555023, 0.05989670008420944, 0.11322733014822006, -0.03962987661361694, 0.00865792203694582, 0.048440344631671906, -0.015009674243628979, 0.0724915862083435, -0.027390392497181892, -0.04293210059404373, 0.01679571159183979, 0.017500607296824455, 0.008871747180819511, 0.03372522443532944, 0.08152657747268677, -0.024098634719848633, -0.028936615213751793, 0.025948416441679, 0.013447280041873455, -0.036376576870679855, -0.044950809329748154, 0.05926044285297394, -0.05358259752392769, -0.0070741842500865
# ...

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_pinecone import PineconeVectorStore
from langchain_core.tools import tool
from pinecone import Pinecone, ServerlessSpec
import time

# %%
# 获取脚本所在目录
SCRIPT_DIR = Path.cwd()
DATA_DIR = SCRIPT_DIR / "data"

# 确保 data 目录存在
DATA_DIR.mkdir(exist_ok=True)

# 加载环境变量
load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# 初始化模型
model = init_chat_model("groq:llama-3.3-70b-versatile", api_key=GROQ_API_KEY)

PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")

# %%
print("\n[1/6] 文档加载...")
sample_text = """LangChain 是一个用于构建 LLM 应用的框架。

它提供了以下核心组件：
1. Models - 语言模型接口
2. Prompts - 提示词模板
3. Chains - 链式调用
4. Agents - 智能代理

RAG (Retrieval-Augmented Generation) 是 LangChain 的核心应用场景之一。"""

doc_path = DATA_DIR / "langchain_intro.txt"
with open(doc_path, "w", encoding="utf-8") as f:
    f.write(sample_text)

loader = TextLoader(doc_path, encoding="utf-8")
documents = loader.load()
print(f"  [OK] 加载了 {len(documents)} 个文档")
# Out:
# [1/6] 文档加载...
#   [OK] 加载了 1 个文档

# %%
print("\n[2/6] 文本分割...")
splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=30,
    separators=["\n\n", "\n", "。", "！", "？", " ", ""]
)
chunks = splitter.split_documents(documents)
print(f"  [OK] 分割为 {len(chunks)} 个块")
# Out:
# [2/6] 文本分割...
#   [OK] 分割为 3 个块

# %%
print("\n[3/6] 向量嵌入 (首次运行会下载模型)...")
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
vector = embeddings.embed_query("LangChain 是什么")
print(f"  [OK] 向量维度: {len(vector)}")
# Out:
# [3/6] 向量嵌入 (首次运行会下载模型)...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   [OK] 向量维度: 384

# %%
print("\n[4/6] Pinecone 设置...")

pc = Pinecone(api_key=PINECONE_API_KEY)
index_name = "langchain-rag-demo"
dimension = 384

existing_indexes = [idx.name for idx in pc.list_indexes()]
if index_name in existing_indexes:
    print(f"  [OK] 索引已存在")
    index = pc.Index(index_name)
else:
    print(f"  创建新索引...")
    pc.create_index(
        name=index_name,
        dimension=dimension,
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region="us-east-1")
    )
    time.sleep(10)
    index = pc.Index(index_name)
    print(f"  [OK] 索引创建完成")
# Out:
# [4/6] Pinecone 设置...
#   创建新索引...
#   [OK] 索引创建完成

# %%
print(pc.list_indexes())
# Out:
# [{
#     "name": "langchain-rag-demo",
#     "metric": "cosine",
#     "host": "langchain-rag-demo-eib5hb2.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "cloud": "aws",
#             "region": "us-east-1"
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 384,
#     "deletion_protection": "disabled",
#     "tags": null
# }]

# %%
import requests
requests.get("https://api.pinecone.io")
# Out:
# <Response [401]>

# %%
from pinecone import Pinecone

pc = Pinecone(api_key=PINECONE_API_KEY)
print("\n[5/6] 文档索引...")
vectorstore = PineconeVectorStore.from_documents(
    documents=chunks,
    embedding=embeddings,
    index_name=index_name
)
print(f"  [OK] {len(chunks)} 个文档块已索引")
# Out:
# [5/6] 文档索引...
#   [OK] 3 个文档块已索引

# %%
print("\n[6/6] RAG 问答...")
@tool
def search_knowledge_base(query: str) -> str:
    """在知识库中搜索相关信息"""
    docs = vectorstore.similarity_search(query, k=2)
    return "\n\n".join([doc.page_content for doc in docs])

from langchain.agents import create_agent
agent = create_agent(
    model=model,
    tools=[search_knowledge_base],
    system_prompt="你是一个助手，可以访问知识库。使用 search_knowledge_base 工具搜索相关信息，然后回答问题。"
)

question = "LangChain 有哪些核心组件？"
print(f"\n  问题: {question}")
try:
    response = agent.invoke({"messages": [{"role": "user", "content": question}]})
    print(f"  回答: {response['messages'][-1].content}")
    print(f"\n  [OK] RAG 问答完成")
except Exception as e:
    print(f"  [错误] RAG 问答失败（Groq 工具调用问题）")
    print(f"  提示: 这是 Groq 处理中文工具调用的偶发问题，不影响其他功能")
# Out:
# [6/6] RAG 问答...
#
#   问题: LangChain 有哪些核心组件？
#   [错误] RAG 问答失败（Groq 工具调用问题）
#   提示: 这是 Groq 处理中文工具调用的偶发问题，不影响其他功能

# %%
print("\n" + "=" * 70)
print(" LangChain 1.0 - RAG Basics 快速演示")
print("=" * 70)

# 示例 1: 文档加载
print("\n[1/6] 文档加载...")
sample_text = """LangChain 是一个用于构建 LLM 应用的框架。

它提供了以下核心组件：
1. Models - 语言模型接口
2. Prompts - 提示词模板
3. Chains - 链式调用
4. Agents - 智能代理

RAG (Retrieval-Augmented Generation) 是 LangChain 的核心应用场景之一。"""

doc_path = DATA_DIR / "langchain_intro.txt"
with open(doc_path, "w", encoding="utf-8") as f:
    f.write(sample_text)

loader = TextLoader(doc_path, encoding="utf-8")
documents = loader.load()
print(f"  [OK] 加载了 {len(documents)} 个文档")

# 示例 2: 文本分割
print("\n[2/6] 文本分割...")
splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=50,
    separators=["\n\n", "\n", "。", "！", "？", " ", ""]
)
chunks = splitter.split_documents(documents)
print(f"  [OK] 分割为 {len(chunks)} 个块")

# 示例 3: 向量嵌入
print("\n[3/6] 向量嵌入 (首次运行会下载模型)...")
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
vector = embeddings.embed_query("LangChain 是什么")
print(f"  [OK] 向量维度: {len(vector)}")

# 示例 4-6: Pinecone 相关
if PINECONE_API_KEY:
    print("\n[4/6] Pinecone 设置...")
    try:
        pc = Pinecone(api_key=PINECONE_API_KEY)
        index_name = "langchain-rag-demo"
        dimension = 384

        existing_indexes = [idx.name for idx in pc.list_indexes()]
        if index_name in existing_indexes:
            print(f"  [OK] 索引已存在")
            index = pc.Index(index_name)
        else:
            print(f"  创建新索引...")
            pc.create_index(
                name=index_name,
                dimension=dimension,
                metric="cosine",
                spec=ServerlessSpec(cloud="aws", region="us-east-1")
            )
            time.sleep(10)
            index = pc.Index(index_name)
            print(f"  [OK] 索引创建完成")

        print("\n[5/6] 文档索引...")
        vectorstore = PineconeVectorStore.from_documents(
            documents=chunks,
            embedding=embeddings,
            index_name=index_name
        )
        print(f"  [OK] {len(chunks)} 个文档块已索引")

        print("\n[6/6] RAG 问答...")
        @tool
        def search_knowledge_base(query: str) -> str:
            """在知识库中搜索相关信息"""
            docs = vectorstore.similarity_search(query, k=2)
            return "\n\n".join([doc.page_content for doc in docs])

        from langchain.agents import create_agent
        agent = create_agent(
            model=model,
            tools=[search_knowledge_base],
            system_prompt="你是一个助手，可以访问知识库。使用 search_knowledge_base 工具搜索相关信息，然后回答问题。"
        )

        question = "LangChain 有哪些核心组件？"
        print(f"\n  问题: {question}")
        try:
            response = agent.invoke({"messages": [{"role": "user", "content": question}]})
            print(f"  回答: {response['messages'][-1].content}")
            print(f"\n  [OK] RAG 问答完成")
        except Exception as e:
            print(f"  [错误] RAG 问答失败（Groq 工具调用问题）")
            print(f"  提示: 这是 Groq 处理中文工具调用的偶发问题，不影响其他功能")

    except Exception as e:
        print(f"  [错误] Pinecone 操作失败: {e}")
else:
    print("\n[4-6] 跳过 Pinecone 相关示例（未设置 API key）")
# Out:
# ...
#  LangChain 1.0 - RAG Basics 快速演示
# ...
#
# [1/6] 文档加载...
#   [OK] 加载了 1 个文档
#
# [2/6] 文本分割...
#   [OK] 分割为 1 个块
#
# [3/6] 向量嵌入 (首次运行会下载模型)...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   [OK] 向量维度: 384
#
# [4/6] Pinecone 设置...
#   [OK] 索引已存在
#
# [5/6] 文档索引...
#   [OK] 1 个文档块已索引
#
# [6/6] RAG 问答...
#
#   问题: LangChain 有哪些核心组件？
#   回答: LangChain 的核心组件包括 Models、Prompts、Chains 和 Agents。RAG（Retrieval-Augmented Generation）是 LangChain 的核心应用场景之一，主要用于增强语言模型的生成能力。
#
#   [OK] RAG 问答完成
